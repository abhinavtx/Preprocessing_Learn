# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('nyc.csv', index_col= 'id')
df.head()
# Out:
#                                                   name  host_id    host_name  \
# id
# 2539                Clean & quiet apt home by the park     2787         John
# 2595                             Skylit Midtown Castle     2845     Jennifer
# 3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#      neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# id
# 2539            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 2595           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 3647           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3831            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 5022           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#       price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# id
# 2539    149               1                  9  2018-10-19               0.21
# 2595    225               1                 45  2019-05-21               0.38
# 3647    150               3                  0         NaN                NaN
# 3831     89               1                270  2019-07-05               4.64
# 5022     80              10                  9  2018-11-19               0.10
#
#       calculated_host_listings_count  availability_365
# id
# 2539                               6               365
# 2595                               2               355
# 3647                               1               365
# 3831                               1               194
# 5022                               1                 0

# %%
df[(df['host_id'] == 2845) & (df['host_name'] == 'John') & (df['price'] > 80)]
# Out:
# Empty DataFrame
# Columns: [name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %%
df.head().sort_values(by='price', ascending = False)
# Out:
#                                                   name  host_id    host_name  \
# id
# 2595                             Skylit Midtown Castle     2845     Jennifer
# 3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 2539                Clean & quiet apt home by the park     2787         John
# 3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#      neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# id
# 2595           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 3647           Manhattan        Harlem  40.80902  -73.94190     Private room
# 2539            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 3831            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 5022           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#       price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# id
# 2595    225               1                 45  2019-05-21               0.38
# 3647    150               3                  0         NaN                NaN
# 2539    149               1                  9  2018-10-19               0.21
# 3831     89               1                270  2019-07-05               4.64
# 5022     80              10                  9  2018-11-19               0.10
#
#       calculated_host_listings_count  availability_365
# id
# 2595                               2               355
# 3647                               1               365
# 2539                               6               365
# 3831                               1               194
# 5022                               1                 0

# %%
jr = df[(df['host_name'] == 'John') & (df['neighbourhood_group'] == 'Brooklyn')]
jr[(jr['price'] == jr['price'].max()) | (jr['price'] == jr['price'].min() ) ].sort_values(by = 'price', ascending = False)
# Out:
#                                                        name    host_id  \
# id
# 8069030                                   Clinton Hill Flat   42619297
# 11553360                                             King 7   42619297
# 20216511  Beautiful NYC Apartment in Popular Brooklyn sp...  132735454
# 21753773                                            oasis 2  156505456
#
#          host_name neighbourhood_group  neighbourhood  latitude  longitude  \
# id
# 8069030       John            Brooklyn   Clinton Hill  40.69242  -73.96828
# 11553360      John            Brooklyn    Fort Greene  40.69413  -73.97230
# 20216511      John            Brooklyn       Bushwick  40.69549  -73.91838
# 21753773      John            Brooklyn  East New York  40.66114  -73.88889
#
#                 room_type  price  minimum_nights  number_of_reviews  \
# id
# 8069030   Entire home/apt    999               2                141
# 11553360  Entire home/apt    999               2                 94
# 20216511     Private room     30               1                  4
# 21753773     Private room     30               3                 28
#
#          last_review  reviews_per_month  calculated_host_listings_count  \
# id
# 8069030   2019-04-28               3.04                               2
# 11553360  2019-06-02               2.85                               2
# 20216511  2017-08-19               0.17                               1
# 21753773  2019-05-28               1.43                              13
#
#           availability_365
# id
# 8069030                 67
# 11553360               361
# 20216511                 0
# 21753773                90

# %%
df.isna().sum()
# Out:
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
print("The perentage of nan values are: ")
df.isna().mean()*100
# Out:
# The perentage of nan values are:
# name                               0.032723
# host_id                            0.000000
# host_name                          0.042949
# neighbourhood_group                0.000000
# neighbourhood                      0.000000
# latitude                           0.000000
# longitude                          0.000000
# room_type                          0.000000
# price                              0.000000
# minimum_nights                     0.000000
# number_of_reviews                  0.000000
# last_review                       20.558339
# reviews_per_month                 20.558339
# calculated_host_listings_count     0.000000
# availability_365                   0.000000
# dtype: float64

# %%
df.shape
# As we see last review and reviews per month are highly empty so dropping the entire column
# Out:
# (48895, 15)

# %%
df.drop(['last_review', 'reviews_per_month'], axis=1, inplace=True)
df.isna().sum()
# Out:
# name                              16
# host_id                            0
# host_name                         21
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           0
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64

# %%
print("Rows with nan values: ")
df[df.isna().any(axis=1) & (df['price'] > 100)]
# Out:
# Rows with nan values:
#                                                        name    host_id  \
# id
# 1615764                                                 NaN    6676776
# 2232600                                                 NaN   11395220
# 4209595                                                 NaN   20700823
# 4370230                                                 NaN   22686810
# 4581788                                                 NaN   21600904
# 4763327                 Luxurious, best location, spa inc'l   24576978
# 6992973                     1 Bedroom in Prime Williamsburg    5162530
# 9325951                                                 NaN   33377685
# 9787590                                                 NaN   50448556
# 12113879     Sunny, Large West Village 1 BR Near Everything    5300585
# 12988898                                                NaN   71552588
# 21787094         Spacious and Bright Midtown East Apartment     415290
# 21867710  Amazing room in the centre on Manhatten! Welcome!  159156636
# 21901156  Best Deal! Lovely place in Manhattan! Time Squ...  159156636
# 21990808                 ***SLEEPING IN THE GOLDEN PLACE***  159156636
# 22275821                                                NaN   49662398
# 23660605    Private Bedroom w/ Balcony view of Central Park  177146433
# 25180572                     Beautiful Cozy Studio Apt. UWS  119609345
#
#          host_name neighbourhood_group      neighbourhood  latitude  \
# id
# 1615764      Peter           Manhattan  Battery Park City  40.71239
# 2232600       Anna           Manhattan       East Village  40.73215
# 4209595      Jesse           Manhattan  Greenwich Village  40.73473
# 4370230    Michaël           Manhattan             Nolita  40.72046
# 4581788      Lucie            Brooklyn       Williamsburg  40.71370
# 4763327        NaN            Brooklyn         Greenpoint  40.72035
# 6992973        NaN            Brooklyn       Williamsburg  40.71838
# 9325951   Jonathan           Manhattan     Hell's Kitchen  40.76436
# 9787590     Miguel           Manhattan             Harlem  40.80316
# 12113879       NaN           Manhattan            Chelsea  40.73949
# 12988898    Andrea               Bronx            Fordham  40.86032
# 21787094       NaN           Manhattan    Upper East Side  40.76436
# 21867710       NaN           Manhattan     Hell's Kitchen  40.75668
# 21901156       NaN           Manhattan     Hell's Kitchen  40.75656
# 21990808       NaN           Manhattan     Hell's Kitchen  40.75835
# 22275821  Kathleen            Brooklyn           Bushwick  40.69546
# 23660605       NaN           Manhattan        East Harlem  40.79766
# 25180572       NaN           Manhattan    Upper West Side  40.77701
#
#           longitude        room_type  price  minimum_nights  \
# id
# 1615764   -74.01620  Entire home/apt    400            1000
# 2232600   -73.98821  Entire home/apt    200               1
# 4209595   -73.99244  Entire home/apt    225               1
# 4370230   -73.99550  Entire home/apt    215               7
# 4581788   -73.94378     Private room    150               1
# 4763327   -73.95355  Entire home/apt    195               1
# 6992973   -73.95630  Entire home/apt    145               1
# 9325951   -73.98573  Entire home/apt    190               4
# 9787590   -73.95189  Entire home/apt    300               5
# 12113879  -73.99801  Entire home/apt    220               4
# 12988898  -73.88493      Shared room    130               1
# 21787094  -73.96836  Entire home/apt    325               1
# 21867710  -73.99097     Private room    120               1
# 21901156  -73.99063     Private room    120               1
# 21990808  -73.99065     Private room    120               1
# 22275821  -73.92741  Entire home/apt    110               4
# 23660605  -73.94824     Private room    139               1
# 25180572  -73.97667  Entire home/apt    180               4
#
#           number_of_reviews  calculated_host_listings_count  availability_365
# id
# 1615764                   0                               1               362
# 2232600                  28                               1               341
# 4209595                   1                               1                 0
# 4370230                   5                               1                 0
# 4581788                   0                               1                 0
# 4763327                   1                               1                 0
# 6992973                   0                               1                 0
# 9325951                   1                               1                 0
# 9787590                   0                               5                 0
# 12113879                 81                               1               217
# 12988898                  0                               1               365
# 21787094                  0                               1                 0
# 21867710                 89                               3                 0
# 21901156                109                               3                 0
# 21990808                 88                               3                 0
# 22275821                  5                               1                 0
# 23660605                  6                               1                 0
# 25180572                  0                               1                 0

# %%
df['name'].fillna(value = 'Anonymous', inplace = True)
df['host_name'].fillna(value = 'Anonymous', inplace = True)
df.isna().sum()
# Out:
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df['price'].median()
# Out:
# 106.0

# %%
# Finding the number of unique values in the column
print("Finding the number of unique values to each column for making dummmies: ")
df.nunique()
# Out:
# Finding the number of unique values to each column for making dummmies:
# name                              47906
# host_id                           37457
# host_name                         11453
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %%
## Now using group by function
neighbourHood = df['price'].groupby(df['neighbourhood_group'])
rooms = df['price'].groupby(df['room_type'])
print("Mean value of airbnb for these neighbourhood group are: ")
print(neighbourHood.mean())
print("\n Mean value of room types for these room types are: ")
print(rooms.mean())
# Out:
# Mean value of airbnb for these neighbourhood group are:
# neighbourhood_group
# Bronx             87.496792
# Brooklyn         124.383207
# Manhattan        196.875814
# Queens            99.517649
# Staten Island    114.812332
# Name: price, dtype: float64
#
#  Mean value of room types for these room types are:
# room_type
# Entire home/apt    211.794246
# Private room        89.780973
# Shared room         70.127586
# Name: price, dtype: float64

# %%
## Now plotting them for neighbourhood
neighbour = df.neighbourhood_group.unique()
neimean = (neighbourHood.mean()).to_list()
print(type(neimean))
print(neighbour)
plt.bar(neighbour,neimean)
#plt.xlabel("Neighbourhood")
#plt.ylabel("Neighbourhood price mean")
# Out:
# <class 'list'>
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# <BarContainer object of 5 artists>

# %%
roomCost = df.room_type.unique()
roomMean = rooms.mean().to_list()
plt.plot(roomCost, roomMean)

# %%
## Making neighbourhood group and room_type to be dummies
dfRoom = pd.get_dummies(df['room_type'])
dfNG = pd.get_dummies(df['neighbourhood_group'])
## We know that after using get_dummies() we need to remove one column to reduce collinearity
#dfRoom.drop(['Entire home/apt'], axis = 1, inplace = True)
#dfNG.drop(['Bronx'], axis = 1, inplace = True)
print(dfRoom.head())
print(dfNG.head())
# Out:
#       Entire home/apt  Private room  Shared room
# id
# 2539            False          True        False
# 2595             True         False        False
# 3647            False          True        False
# 3831             True         False        False
# 5022             True         False        False
#       Bronx  Brooklyn  Manhattan  Queens  Staten Island
# id
# 2539  False      True      False   False          False
# 2595  False     False       True   False          False
# 3647  False     False       True   False          False
# 3831  False      True      False   False          False
# 5022  False     False       True   False          False

# %%
df.drop(['room_type'], axis = 1 ,inplace=True)
df.drop(['neighbourhood_group'], axis = 1, inplace= True)

# %%
dfDummy = pd.concat([dfRoom,dfNG], axis=1)
dfDummy
# Out:
#           Entire home/apt  Private room  Shared room  Bronx  Brooklyn  \
# id
# 2539                False          True        False  False      True
# 2595                 True         False        False  False     False
# 3647                False          True        False  False     False
# 3831                 True         False        False  False      True
# 5022                 True         False        False  False     False
# ...                   ...           ...          ...    ...       ...
# 36484665            False          True        False  False      True
# 36485057            False          True        False  False      True
# 36485431             True         False        False  False     False
# 36485609            False         False         True  False     False
# 36487245            False          True        False  False     False
#
#           Manhattan  Queens  Staten Island
# id
# 2539          False   False          False
# 2595           True   False          False
# 3647           True   False          False
# 3831          False   False          False
# 5022           True   False          False
# ...             ...     ...            ...
# 36484665      False   False          False
# 36485057      False   False          False
# 36485431       True   False          False
# 36485609       True   False          False
# 36487245       True   False          False
#
# [48895 rows x 8 columns]

# %%
# Now conconating into the original dataframe
df = pd.concat([df, dfDummy], axis=1)
encodedColumn = ['Entire home/apt','Private room','Shared room','Bronx','Brooklyn','Manhattan','Queens','Staten Island']
df.set_index = 'id'
df[encodedColumn] = df[encodedColumn].astype(int)
df.head()
# Out:
#                                                   name  host_id    host_name  \
# id
# 2539                Clean & quiet apt home by the park     2787         John
# 2595                             Skylit Midtown Castle     2845     Jennifer
# 3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#      neighbourhood  latitude  longitude  price  minimum_nights  \
# id
# 2539    Kensington  40.64749  -73.97237    149               1
# 2595       Midtown  40.75362  -73.98377    225               1
# 3647        Harlem  40.80902  -73.94190    150               3
# 3831  Clinton Hill  40.68514  -73.95976     89               1
# 5022   East Harlem  40.79851  -73.94399     80              10
#
#       number_of_reviews  calculated_host_listings_count  availability_365  \
# id
# 2539                  9                               6               365
# 2595                 45                               2               355
# 3647                  0                               1               365
# 3831                270                               1               194
# 5022                  9                               1                 0
#
#       Entire home/apt  Private room  Shared room  Bronx  Brooklyn  Manhattan  \
# id
# 2539                0             1            0      0         1          0
# 2595                1             0            0      0         0          1
# 3647                0             1            0      0         0          1
# 3831                1             0            0      0         1          0
# 5022                1             0            0      0         0          1
#
#       Queens  Staten Island
# id
# 2539       0              0
# 2595       0              0
# 3647       0              0
# 3831       0              0
# 5022       0              0

# %%
columnScale = ['latitude','longitude','minimum_nights','number_of_reviews','calculated_host_listings_count','availability_365','Entire home/apt','Private room','Shared room','Bronx','Brooklyn','Manhattan','Queens','Staten Island']
data = df.loc[:,columnScale]
valueScale = df.loc[:, columnScale]
# Min-Max Scaling using NumPy
min_values = np.min(valueScale, axis=0)
max_values = np.max(valueScale, axis=0)
ScaledValue = (valueScale - min_values) / (max_values - min_values)
df.loc[:, columnScale] = ScaledValue

print("Now in this we have applied min-max scaling (feature scaling)")
print("The shape of the matrix is: ", df.shape )
df.head()
## In scaling we have not scaled price
# Out:
# Now in this we have applied min-max scaling (feature scaling)
# The shape of the matrix is:  (48895, 19)
#                                                   name  host_id    host_name  \
# id
# 2539                Clean & quiet apt home by the park     2787         John
# 2595                             Skylit Midtown Castle     2845     Jennifer
# 3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#      neighbourhood  latitude  longitude  price  minimum_nights  \
# id
# 2539    Kensington  0.357393   0.511921    149        0.000000
# 2595       Midtown  0.614199   0.490469    225        0.000000
# 3647        Harlem  0.748252   0.569257    150        0.001601
# 3831  Clinton Hill  0.448496   0.535649     89        0.000000
# 5022   East Harlem  0.722820   0.565324     80        0.007206
#
#       number_of_reviews  calculated_host_listings_count  availability_365  \
# id
# 2539           0.014308                        0.015337          1.000000
# 2595           0.071542                        0.003067          0.972603
# 3647           0.000000                        0.000000          1.000000
# 3831           0.429253                        0.000000          0.531507
# 5022           0.014308                        0.000000          0.000000
#
#       Entire home/apt  Private room  Shared room  Bronx  Brooklyn  Manhattan  \
# id
# 2539                0             1            0      0         1          0
# 2595                1             0            0      0         0          1
# 3647                0             1            0      0         0          1
# 3831                1             0            0      0         1          0
# 5022                1             0            0      0         0          1
#
#       Queens  Staten Island
# id
# 2539       0              0
# 2595       0              0
# 3647       0              0
# 3831       0              0
# 5022       0              0

# %%
#Now again using correlation matrix to find correlation between elements for feature selection

# Calculate the correlation matrix
correlation_matrix = df.loc[:,columnScale].corr()

# Set a correlation threshold
correlation_threshold = 0.75

# Identify pairs of features with high correlation
correlated_pairs = []
for i in range(len(correlation_matrix.columns)):
    for j in range(i + 1, len(correlation_matrix.columns)):
        if abs(correlation_matrix.iloc[i, j]) >= correlation_threshold:
            correlated_pairs.append((correlation_matrix.columns[i], correlation_matrix.columns[j]))
ans = ''
# Remove one feature from each correlated pair
for feature1, feature2 in correlated_pairs:
    # Drop one of the features (you can choose based on your criteria)
    df.drop(feature2, axis=1, inplace=True)
    print("Dataframe removed after feature selection is: ",feature2)
    ans = feature2
# Display the DataFrame after removing correlated features
print("DataFrame after removing correlated features:")
print(df.shape)
print("The correlation matrix is: \n")
correlation_matrix
# Out:
# Dataframe removed after feature selection is:  Private room
# DataFrame after removing correlated features:
# (48895, 18)
# The correlation matrix is:
#                                 latitude  longitude  minimum_nights  \
# latitude                        1.000000   0.084788        0.024869
# longitude                       0.084788   1.000000       -0.062747
# minimum_nights                  0.024869  -0.062747        1.000000
# number_of_reviews              -0.015389   0.059094       -0.080116
# calculated_host_listings_count  0.019517  -0.114713        0.127960
# availability_365               -0.010983   0.082731        0.144303
# Entire home/apt                -0.005712  -0.192143        0.074900
# Private room                    0.004363   0.183613       -0.073837
# Shared room                     0.004473   0.029812       -0.004218
# Bronx                           0.330669   0.221315       -0.018186
# Brooklyn                       -0.672932   0.017735       -0.039658
# Manhattan                       0.590639  -0.433531        0.067362
# Queens                          0.017145   0.622749       -0.032629
# Staten Island                  -0.190894  -0.291841       -0.009400
#
#                                 number_of_reviews  \
# latitude                                -0.015389
# longitude                                0.059094
# minimum_nights                          -0.080116
# number_of_reviews                        1.000000
# calculated_host_listings_count          -0.072376
# availability_365                         0.172028
# Entire home/apt                         -0.010087
# Private room                             0.017253
# Shared room                             -0.023355
# Bronx                                    0.009258
# Brooklyn                                 0.017414
# Manhattan                               -0.045820
# Queens                                   0.035967
# Staten Island                            0.015088
#
#                                 calculated_host_listings_count  \
# latitude                                              0.019517
# longitude                                            -0.114713
# minimum_nights                                        0.127960
# number_of_reviews                                    -0.072376
# calculated_host_listings_count                        1.000000
# availability_365                                      0.225701
# Entire home/apt                                       0.112193
# Private room                                         -0.108945
# Shared room                                          -0.011737
# Bronx                                                -0.022511
# Brooklyn                                             -0.123234
# Manhattan                                             0.152842
# Queens                                               -0.033881
# Staten Island                                        -0.012838
#
#                                 availability_365  Entire home/apt  \
# latitude                               -0.010983        -0.005712
# longitude                               0.082731        -0.192143
# minimum_nights                          0.144303         0.074900
# number_of_reviews                       0.172028        -0.010087
# calculated_host_listings_count          0.225701         0.112193
# availability_365                        1.000000        -0.006804
# Entire home/apt                        -0.006804         1.000000
# Private room                           -0.010986        -0.953470
# Shared room                             0.058294        -0.162144
# Bronx                                   0.060806        -0.052092
# Brooklyn                               -0.079671        -0.073905
# Manhattan                              -0.005434         0.160082
# Queens                                  0.087113        -0.108505
# Staten Island                           0.057885        -0.008391
#
#                                 Private room  Shared room     Bronx  Brooklyn  \
# latitude                            0.004363     0.004473  0.330669 -0.672932
# longitude                           0.183613     0.029812  0.221315  0.017735
# minimum_nights                     -0.073837    -0.004218 -0.018186 -0.039658
# number_of_reviews                   0.017253    -0.023355  0.009258  0.017414
# calculated_host_listings_count     -0.108945    -0.011737 -0.022511 -0.123234
# availability_365                   -0.010986     0.058294  0.060806 -0.079671
# Entire home/apt                    -0.953470    -0.162144 -0.052092 -0.073905
# Private room                        1.000000    -0.142899  0.042765  0.079464
# Shared room                        -0.142899     1.000000  0.031041 -0.017467
# Bronx                               0.042765     0.031041  1.000000 -0.126239
# Brooklyn                            0.079464    -0.017467 -0.126239  1.000000
# Manhattan                          -0.157762    -0.009169 -0.134730 -0.745240
# Queens                              0.100676     0.026693 -0.054693 -0.302527
# Staten Island                       0.008345     0.000233 -0.013245 -0.073265
#
#                                 Manhattan    Queens  Staten Island
# latitude                         0.590639  0.017145      -0.190894
# longitude                       -0.433531  0.622749      -0.291841
# minimum_nights                   0.067362 -0.032629      -0.009400
# number_of_reviews               -0.045820  0.035967       0.015088
# calculated_host_listings_count   0.152842 -0.033881      -0.012838
# availability_365                -0.005434  0.087113       0.057885
# Entire home/apt                  0.160082 -0.108505      -0.008391
# Private room                    -0.157762  0.100676       0.008345
# Shared room                     -0.009169  0.026693       0.000233
# Bronx                           -0.134730 -0.054693      -0.013245
# Brooklyn                        -0.745240 -0.302527      -0.073265
# Manhattan                        1.000000 -0.322875      -0.078193
# Queens                          -0.322875  1.000000      -0.031742
# Staten Island                   -0.078193 -0.031742       1.000000

# %%
df.sort_values(by='id', ascending=True, inplace=True)
df.head()
# Out:
#                                                   name  host_id    host_name  \
# id
# 2539                Clean & quiet apt home by the park     2787         John
# 2595                             Skylit Midtown Castle     2845     Jennifer
# 3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#      neighbourhood  latitude  longitude  price  minimum_nights  \
# id
# 2539    Kensington  0.357393   0.511921    149        0.000000
# 2595       Midtown  0.614199   0.490469    225        0.000000
# 3647        Harlem  0.748252   0.569257    150        0.001601
# 3831  Clinton Hill  0.448496   0.535649     89        0.000000
# 5022   East Harlem  0.722820   0.565324     80        0.007206
#
#       number_of_reviews  calculated_host_listings_count  availability_365  \
# id
# 2539           0.014308                        0.015337          1.000000
# 2595           0.071542                        0.003067          0.972603
# 3647           0.000000                        0.000000          1.000000
# 3831           0.429253                        0.000000          0.531507
# 5022           0.014308                        0.000000          0.000000
#
#       Entire home/apt  Shared room  Bronx  Brooklyn  Manhattan  Queens  \
# id
# 2539                0            0      0         1          0       0
# 2595                1            0      0         0          1       0
# 3647                0            0      0         0          1       0
# 3831                1            0      0         1          0       0
# 5022                1            0      0         0          1       0
#
#       Staten Island
# id
# 2539              0
# 2595              0
# 3647              0
# 3831              0
# 5022              0

# %% [markdown]
# ### Now we shall be implementing PCA using numpy and pandas

# %%
data.drop([ans], axis= 1, inplace=True)
data.head()
# Now on this data we shall be implementing PCA
# Out:
#       latitude  longitude  minimum_nights  number_of_reviews  \
# id
# 2539  40.64749  -73.97237               1                  9
# 2595  40.75362  -73.98377               1                 45
# 3647  40.80902  -73.94190               3                  0
# 3831  40.68514  -73.95976               1                270
# 5022  40.79851  -73.94399              10                  9
#
#       calculated_host_listings_count  availability_365  Entire home/apt  \
# id
# 2539                               6               365                0
# 2595                               2               355                1
# 3647                               1               365                0
# 3831                               1               194                1
# 5022                               1                 0                1
#
#       Shared room  Bronx  Brooklyn  Manhattan  Queens  Staten Island
# id
# 2539            0      0         1          0       0              0
# 2595            0      0         0          1       0              0
# 3647            0      0         0          1       0              0
# 3831            0      0         1          0       0              0
# 5022            0      0         0          1       0              0

# %%
# Normalise the data
data = (data - data.mean()) / data.std()
data.head()
# Out:
#       latitude  longitude  minimum_nights  number_of_reviews  \
# id
# 2539 -1.493834  -0.437648       -0.293993          -0.320410
# 2595  0.452431  -0.684632       -0.293993           0.487660
# 3647  1.468384   0.222494       -0.196482          -0.522428
# 3831 -0.803389  -0.164448       -0.293993           5.538099
# 5022  1.275647   0.177214        0.144805          -0.320410
#
#       calculated_host_listings_count  availability_365  Entire home/apt  \
# id
# 2539                       -0.034716          1.916231        -1.040123
# 2595                       -0.156103          1.840256         0.961405
# 3647                       -0.186450          1.916231        -1.040123
# 3831                       -0.186450          0.617059         0.961405
# 5022                       -0.186450         -0.856856         0.961405
#
#       Shared room     Bronx  Brooklyn  Manhattan    Queens  Staten Island
# id
# 2539    -0.155886 -0.151069  1.196693  -0.891824 -0.362031      -0.087676
# 2595    -0.155886 -0.151069 -0.835619   1.121275 -0.362031      -0.087676
# 3647    -0.155886 -0.151069 -0.835619   1.121275 -0.362031      -0.087676
# 3831    -0.155886 -0.151069  1.196693  -0.891824 -0.362031      -0.087676
# 5022    -0.155886 -0.151069 -0.835619   1.121275 -0.362031      -0.087676

# %%
# Calculate the covariance matrix
cov_mat = data.cov()
cov_mat
# Out:
#                                 latitude  longitude  minimum_nights  \
# latitude                        1.000000   0.084788        0.024869
# longitude                       0.084788   1.000000       -0.062747
# minimum_nights                  0.024869  -0.062747        1.000000
# number_of_reviews              -0.015389   0.059094       -0.080116
# calculated_host_listings_count  0.019517  -0.114713        0.127960
# availability_365               -0.010983   0.082731        0.144303
# Entire home/apt                -0.005712  -0.192143        0.074900
# Shared room                     0.004473   0.029812       -0.004218
# Bronx                           0.330669   0.221315       -0.018186
# Brooklyn                       -0.672932   0.017735       -0.039658
# Manhattan                       0.590639  -0.433531        0.067362
# Queens                          0.017145   0.622749       -0.032629
# Staten Island                  -0.190894  -0.291841       -0.009400
#
#                                 number_of_reviews  \
# latitude                                -0.015389
# longitude                                0.059094
# minimum_nights                          -0.080116
# number_of_reviews                        1.000000
# calculated_host_listings_count          -0.072376
# availability_365                         0.172028
# Entire home/apt                         -0.010087
# Shared room                             -0.023355
# Bronx                                    0.009258
# Brooklyn                                 0.017414
# Manhattan                               -0.045820
# Queens                                   0.035967
# Staten Island                            0.015088
#
#                                 calculated_host_listings_count  \
# latitude                                              0.019517
# longitude                                            -0.114713
# minimum_nights                                        0.127960
# number_of_reviews                                    -0.072376
# calculated_host_listings_count                        1.000000
# availability_365                                      0.225701
# Entire home/apt                                       0.112193
# Shared room                                          -0.011737
# Bronx                                                -0.022511
# Brooklyn                                             -0.123234
# Manhattan                                             0.152842
# Queens                                               -0.033881
# Staten Island                                        -0.012838
#
#                                 availability_365  Entire home/apt  \
# latitude                               -0.010983        -0.005712
# longitude                               0.082731        -0.192143
# minimum_nights                          0.144303         0.074900
# number_of_reviews                       0.172028        -0.010087
# calculated_host_listings_count          0.225701         0.112193
# availability_365                        1.000000        -0.006804
# Entire home/apt                        -0.006804         1.000000
# Shared room                             0.058294        -0.162144
# Bronx                                   0.060806        -0.052092
# Brooklyn                               -0.079671        -0.073905
# Manhattan                              -0.005434         0.160082
# Queens                                  0.087113        -0.108505
# Staten Island                           0.057885        -0.008391
#
#                                 Shared room     Bronx  Brooklyn  Manhattan  \
# latitude                           0.004473  0.330669 -0.672932   0.590639
# longitude                          0.029812  0.221315  0.017735  -0.433531
# minimum_nights                    -0.004218 -0.018186 -0.039658   0.067362
# number_of_reviews                 -0.023355  0.009258  0.017414  -0.045820
# calculated_host_listings_count    -0.011737 -0.022511 -0.123234   0.152842
# availability_365                   0.058294  0.060806 -0.079671  -0.005434
# Entire home/apt                   -0.162144 -0.052092 -0.073905   0.160082
# Shared room                        1.000000  0.031041 -0.017467  -0.009169
# Bronx                              0.031041  1.000000 -0.126239  -0.134730
# Brooklyn                          -0.017467 -0.126239  1.000000  -0.745240
# Manhattan                         -0.009169 -0.134730 -0.745240   1.000000
# Queens                             0.026693 -0.054693 -0.302527  -0.322875
# Staten Island                      0.000233 -0.013245 -0.073265  -0.078193
#
#                                   Queens  Staten Island
# latitude                        0.017145      -0.190894
# longitude                       0.622749      -0.291841
# minimum_nights                 -0.032629      -0.009400
# number_of_reviews               0.035967       0.015088
# calculated_host_listings_count -0.033881      -0.012838
# availability_365                0.087113       0.057885
# Entire home/apt                -0.108505      -0.008391
# Shared room                     0.026693       0.000233
# Bronx                          -0.054693      -0.013245
# Brooklyn                       -0.302527      -0.073265
# Manhattan                      -0.322875      -0.078193
# Queens                          1.000000      -0.031742
# Staten Island                  -0.031742       1.000000

# %%
# Now calculating eigenvectors and eigen values
eig_values, eig_vectors = np.linalg.eig(cov_mat)

print("The eigen values are: \n", eig_values)
print("The eigen vectors are: \n", eig_vectors)
# Out:
# The eigen values are:
#  [2.47020448e+00 2.00057801e+00 2.07846670e-01 2.88740094e-01
#  1.35494009e+00 6.31688924e-01 8.01428568e-01 8.71652371e-01
#  9.97478244e-01 1.16364748e+00 1.11814217e+00 1.09365290e+00
#  3.65569978e-16]
# The eigen vectors are:
#  [[-4.85208267e-01 -3.10157000e-01 -5.85649666e-01 -5.09403972e-01
#   -1.82969965e-01  3.62028843e-03 -5.01943446e-02  5.36679399e-02
#    1.05375347e-02 -2.84092222e-02  1.11015852e-01  1.17320745e-01
#    9.06264533e-16]
#  [ 2.31768028e-01 -5.84736663e-01  5.51052437e-01 -5.11970562e-01
#    2.47682276e-02 -1.55106910e-03  3.50598340e-02 -1.06973137e-02
#   -5.83680694e-03  1.88436541e-01  2.52034530e-02  2.13743546e-02
#    5.16384107e-16]
#  [-8.88596351e-02  6.13629256e-02  2.06814187e-02  1.16823855e-03
#    4.00711984e-01  2.35565545e-01 -1.53052656e-02  7.60908942e-01
#    1.15376359e-01  2.08714343e-01  3.47477523e-01 -1.22546200e-01
#   -9.52616607e-17]
#  [ 5.21807110e-02 -7.77422650e-02  2.83307262e-03  1.43380879e-02
#    1.53335585e-01  4.43407836e-01  4.63257895e-02  2.04095374e-01
#   -4.37413914e-01 -3.15001479e-01 -3.67328557e-01  5.49189642e-01
#   -3.88349388e-17]
#  [-1.58817935e-01  7.72904649e-02 -1.44666350e-02 -8.86156410e-02
#    5.15823869e-01  4.90570233e-01 -1.89813946e-01 -5.91564863e-01
#   -2.22475018e-02  1.56505155e-01  1.93742277e-01 -7.41917034e-02
#   -9.93583679e-17]
#  [-2.92249298e-02 -1.11370050e-01 -6.36112535e-02  1.60219370e-03
#    6.42952433e-01 -6.75431705e-01 -7.53028590e-02 -3.97784909e-02
#   -1.26771841e-01 -2.30265525e-01  6.07368811e-02  1.81831537e-01
#    1.48868630e-16]
#  [-1.46030148e-01  2.08961717e-01 -1.51221860e-02 -9.88326980e-02
#    1.43963472e-01 -8.14263060e-02  7.56461153e-01 -8.52275489e-02
#    1.40528191e-01  4.33130285e-01 -1.69705493e-01  2.86375117e-01
#    3.52733139e-16]
#  [ 1.73902408e-02 -8.68631582e-02 -9.39752786e-03 -3.42355458e-02
#    1.66589077e-02  9.97723268e-02  5.93758741e-01 -5.70462682e-02
#   -3.20866920e-01 -4.74503163e-01  3.21026220e-01 -4.40101765e-01
#   -3.19907772e-17]
#  [-6.21028820e-02 -2.79499641e-01  1.04175881e-01  3.59798930e-01
#   -1.04839517e-01  9.89776851e-02  1.10317533e-01 -1.04283429e-01
#    4.46381926e-01 -2.32675230e-01  4.71265243e-01  4.72494058e-01
#   -1.87473331e-01]
#  [ 5.27733288e-01  2.77295495e-01 -2.39530245e-01 -2.94660833e-01
#   -4.49164833e-02 -2.18857691e-02 -2.95683351e-02 -1.64735080e-02
#   -1.19045583e-01  6.65722015e-02  2.55473853e-01  1.51110116e-01
#   -6.24546263e-01]
#  [-5.93437083e-01  1.07469157e-01  4.06687668e-01  2.76223641e-02
#   -7.32706222e-02 -8.15187306e-02 -6.89146870e-02  3.50318958e-02
#   -2.01058007e-01 -1.25606994e-02 -8.84621945e-02 -7.86623449e-02
#   -6.30507082e-01]
#  [ 1.32349864e-01 -5.21248282e-01 -3.30792526e-01  3.40673161e-01
#    1.85052534e-01  8.74974593e-02  9.48517157e-02  7.25300911e-03
#    1.19782439e-01  1.59473044e-01 -3.78927510e-01 -2.93132448e-01
#   -4.06275732e-01]
#  [ 2.21348265e-02  2.10301828e-01  7.28104115e-02 -3.55373104e-01
#    1.69527861e-01  9.92686923e-02  2.44521312e-02  4.35017575e-02
#    6.22689025e-01 -4.96454190e-01 -3.45712461e-01 -1.29172207e-01
#   -1.10438059e-01]]

# %%
## Now sorting of eigenvectors
#The eigenvectors with the lowest eigenvalues bear the least information about the distribution of the data; those are the ones can be dropped.
e_indices = np.argsort(eig_values)[::-1]
eigenvectors_sorted = eig_vectors[:,e_indices]
eigenvectors_sorted
# Out:
# array([[-4.85208267e-01, -3.10157000e-01, -1.82969965e-01,
#         -2.84092222e-02,  1.11015852e-01,  1.17320745e-01,
#          1.05375347e-02,  5.36679399e-02, -5.01943446e-02,
#          3.62028843e-03, -5.09403972e-01, -5.85649666e-01,
#          9.06264533e-16],
#        [ 2.31768028e-01, -5.84736663e-01,  2.47682276e-02,
#          1.88436541e-01,  2.52034530e-02,  2.13743546e-02,
#         -5.83680694e-03, -1.06973137e-02,  3.50598340e-02,
#         -1.55106910e-03, -5.11970562e-01,  5.51052437e-01,
#          5.16384107e-16],
#        [-8.88596351e-02,  6.13629256e-02,  4.00711984e-01,
#          2.08714343e-01,  3.47477523e-01, -1.22546200e-01,
#          1.15376359e-01,  7.60908942e-01, -1.53052656e-02,
#          2.35565545e-01,  1.16823855e-03,  2.06814187e-02,
#         -9.52616607e-17],
#        [ 5.21807110e-02, -7.77422650e-02,  1.53335585e-01,
#         -3.15001479e-01, -3.67328557e-01,  5.49189642e-01,
#         -4.37413914e-01,  2.04095374e-01,  4.63257895e-02,
#          4.43407836e-01,  1.43380879e-02,  2.83307262e-03,
#         -3.88349388e-17],
#        [-1.58817935e-01,  7.72904649e-02,  5.15823869e-01,
#          1.56505155e-01,  1.93742277e-01, -7.41917034e-02,
#         -2.22475018e-02, -5.91564863e-01, -1.89813946e-01,
#          4.90570233e-01, -8.86156410e-02, -1.44666350e-02,
#         -9.93583679e-17],
#        [-2.92249298e-02, -1.11370050e-01,  6.42952433e-01,
#         -2.30265525e-01,  6.07368811e-02,  1.81831537e-01,
#         -1.26771841e-01, -3.97784909e-02, -7.53028590e-02,
#         -6.75431705e-01,  1.60219370e-03, -6.36112535e-02,
#          1.48868630e-16],
#        [-1.46030148e-01,  2.08961717e-01,  1.43963472e-01,
#          4.33130285e-01, -1.69705493e-01,  2.86375117e-01,
#          1.40528191e-01, -8.52275489e-02,  7.56461153e-01,
#         -8.14263060e-02, -9.88326980e-02, -1.51221860e-02,
#          3.52733139e-16],
#        [ 1.73902408e-02, -8.68631582e-02,  1.66589077e-02,
#         -4.74503163e-01,  3.21026220e-01, -4.40101765e-01,
#         -3.20866920e-01, -5.70462682e-02,  5.93758741e-01,
#          9.97723268e-02, -3.42355458e-02, -9.39752786e-03,
#         -3.19907772e-17],
#        [-6.21028820e-02, -2.79499641e-01, -1.04839517e-01,
#         -2.32675230e-01,  4.71265243e-01,  4.72494058e-01,
#          4.46381926e-01, -1.04283429e-01,  1.10317533e-01,
#          9.89776851e-02,  3.59798930e-01,  1.04175881e-01,
#         -1.87473331e-01],
#        [ 5.27733288e-01,  2.77295495e-01, -4.49164833e-02,
#          6.65722015e-02,  2.55473853e-01,  1.51110116e-01,
#         -1.19045583e-01, -1.64735080e-02, -2.95683351e-02,
#         -2.18857691e-02, -2.94660833e-01, -2.39530245e-01,
#         -6.24546263e-01],
#        [-5.93437083e-01,  1.07469157e-01, -7.32706222e-02,
#         -1.25606994e-02, -8.84621945e-02, -7.86623449e-02,
#         -2.01058007e-01,  3.50318958e-02, -6.89146870e-02,
#         -8.15187306e-02,  2.76223641e-02,  4.06687668e-01,
#         -6.30507082e-01],
#        [ 1.32349864e-01, -5.21248282e-01,  1.85052534e-01,
#          1.59473044e-01, -3.78927510e-01, -2.93132448e-01,
#          1.19782439e-01,  7.25300911e-03,  9.48517157e-02,
#          8.74974593e-02,  3.40673161e-01, -3.30792526e-01,
#         -4.06275732e-01],
#        [ 2.21348265e-02,  2.10301828e-01,  1.69527861e-01,
#         -4.96454190e-01, -3.45712461e-01, -1.29172207e-01,
#          6.22689025e-01,  4.35017575e-02,  2.44521312e-02,
#          9.92686923e-02, -3.55373104e-01,  7.28104115e-02,
#         -1.10438059e-01]])

# %%
## Now choosing principal components
newList = [i for i in eig_values]
#newList.sort(reverse=True)
#newList

sumList = list()
for i in range(len(newList)):
    sumList.append((newList[i]/sum(newList))*100)
print(newList)
print(sumList)
columnScale.remove('Private room')
# Out:
# [2.470204476902471, 2.000578006664981, 0.20784666968836418, 0.28874009399071726, 1.3549400929127327, 0.6316889244978661, 0.8014285676277808, 0.8716523713725848, 0.9974782441141883, 1.1636474793212954, 1.1181421688329656, 1.09365290407406, 3.655699776422061e-16]
# [19.001572899249766, 15.389061589730616, 1.5988205360643388, 2.2210776460824393, 10.422616099328707, 4.8591455730605055, 6.16483513559831, 6.705018241327572, 7.6729095701091365, 8.951134456317652, 8.601093606407423, 8.412714646723533, 2.8120767510938913e-15]

# %%
eigenData = {'name': columnScale, 'eigenValue' : newList , 'eigenValuePercentage' : sumList}
dfEig = pd.DataFrame(eigenData)
dfEig.sort_values(by='eigenValuePercentage',ascending=False,inplace=True)
dfEig
# Out:
#                               name    eigenValue  eigenValuePercentage
# 0                         latitude  2.470204e+00          1.900157e+01
# 1                        longitude  2.000578e+00          1.538906e+01
# 4   calculated_host_listings_count  1.354940e+00          1.042262e+01
# 9                         Brooklyn  1.163647e+00          8.951134e+00
# 10                       Manhattan  1.118142e+00          8.601094e+00
# 11                          Queens  1.093653e+00          8.412715e+00
# 8                            Bronx  9.974782e-01          7.672910e+00
# 7                      Shared room  8.716524e-01          6.705018e+00
# 6                  Entire home/apt  8.014286e-01          6.164835e+00
# 5                 availability_365  6.316889e-01          4.859146e+00
# 3                number_of_reviews  2.887401e-01          2.221078e+00
# 2                   minimum_nights  2.078467e-01          1.598821e+00
# 12                   Staten Island  3.655700e-16          2.812077e-15

# %%
myValues = dfEig['eigenValuePercentage']
columnName = dfEig['name']
plt.bar(columnName[0:len(myValues)-1], myValues[0:len(myValues)-1])
# Out:
# <BarContainer object of 12 artists>

# %%
myLabels = columnScale
myLabels.pop()
values = dfEig['eigenValuePercentage'].to_numpy()
values = np.delete(values, len(values) - 1)
print(len(values) == len(myLabels))
plt.pie(values, labels= myLabels)
print(myLabels)
# Out:
# True
# ['latitude', 'longitude', 'minimum_nights', 'number_of_reviews', 'calculated_host_listings_count', 'availability_365', 'Entire home/apt', 'Shared room', 'Bronx', 'Brooklyn', 'Manhattan', 'Queens']

# %%
print("This Pie Chart tells about the importance of the feature in the dataset")
# Out:
# This Pie Chart tells about the importance of the feature in the dataset
